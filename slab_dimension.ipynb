# %% [markdown]
# ## BUILDING A SLAB

# %% [markdown]
# From CIS file

# %%
from ase.io import read, write
from ase.build import surface

# Step 1: Load the CIF file
bulk_fe = read('mp-13_Fe.cif')

# Step 2: Create a 2-layer slab
slab = surface(bulk_fe, (1, 1, 0), layers=2)

# Step 3: Adjust the surface size to 30 Å × 30 Å
rep_x = int(30 / (bulk_fe.cell[0, 0] * 2 ** 0.5))  # Repeat along x
rep_y = int(30 / bulk_fe.cell[1, 1])              # Repeat along y
slab = slab.repeat((rep_x, rep_y, 1))

# Step 4: Add a vacuum of 15 Å
slab.center(vacuum=15, axis=2)

# Step 5: Save the slab
write('Fe_110.pdb', slab)  # Save as PDB file
write('Fe_110.xyz', slab)  # Save as XYZ file
write('Fe_100.gro', slab)  # Save as gro file

# %% [markdown]
# ### SLAB DIMENSION

# %%
import numpy as np

# Function to read an XYZ file and extract atomic coordinates (in Ångströms)
def read_xyz_file(xyz_file):
    with open(xyz_file, 'r') as file:
        lines = file.readlines()

    atoms = []
    for line in lines[2:]:  # Skip the first two lines
        parts = line.split()
        if len(parts) < 4:
            continue
        x, y, z = map(float, parts[1:4])  # Extract x, y, z coordinates (in Ångströms)
        atoms.append([x, y, z])

    return np.array(atoms), 'Å'  # Return the coordinates in Ångströms

# Function to read a PDB file and extract atomic coordinates (in Ångströms)
def read_pdb_file(pdb_file):
    with open(pdb_file, 'r') as file:
        lines = file.readlines()

    atoms = []
    for line in lines:
        if line.startswith("ATOM") or line.startswith("HETATM"):
            # Extract x, y, z coordinates from columns 31-38, 39-46, 47-54 (in Ångströms)
            x = float(line[30:38].strip())
            y = float(line[38:46].strip())
            z = float(line[46:54].strip())
            atoms.append([x, y, z])

    return np.array(atoms), 'Å'  # Return the coordinates in Ångströms

# Function to read a GRO file and extract atomic coordinates (in nanometers)
def read_gro_file(gro_file):
    with open(gro_file, 'r') as file:
        lines = file.readlines()

    atoms = []
    for line in lines[2:]:  # Skip the first two lines (title and number of atoms)
        parts = line.split()
        if len(parts) < 5:
            continue
        x, y, z = map(float, parts[3:6])  # Extract x, y, z coordinates (in nm)
        atoms.append([x, y, z])

    return np.array(atoms), 'nm'  # Return the coordinates in nanometers

# Function to calculate the dimensions of the slab
def calculate_dimensions(atoms):
    x_min, y_min, z_min = np.min(atoms, axis=0)
    x_max, y_max, z_max = np.max(atoms, axis=0)

    # Calculate the dimensions
    x_dim = x_max - x_min
    y_dim = y_max - y_min
    z_dim = z_max - z_min

    return x_dim, y_dim, z_dim

# Function to convert coordinates to Ångströms
def convert_to_angstroms(dimensions, unit):
    if unit == 'nm':  # If the unit is nm, convert to Ångströms (1 nm = 10 Å)
        return dimensions * 10
    return dimensions  # Already in Ångströms

# Main function
def main():
    file_path = "md_setup/slab.gro"  # Replace with the path to your .xyz, .pdb, or .gro file

    # Determine the file format based on the file extension
    if file_path.endswith(".xyz"):
        atoms, unit = read_xyz_file(file_path)
        file_type = "XYZ"
    elif file_path.endswith(".pdb"):
        atoms, unit = read_pdb_file(file_path)
        file_type = "PDB"
    elif file_path.endswith(".gro"):
        atoms, unit = read_gro_file(file_path)
        file_type = "GRO"
    else:
        print("Unsupported file format")
        return

    x_dim, y_dim, z_dim = calculate_dimensions(atoms)

    # Convert dimensions to Ångströms (if necessary)
    x_dim_angstrom = convert_to_angstroms(x_dim, unit)
    y_dim_angstrom = convert_to_angstroms(y_dim, unit)
    z_dim_angstrom = convert_to_angstroms(z_dim, unit)

    # Convert dimensions to nanometers (1 Å = 0.1 nm)
    x_dim_nanometer = x_dim_angstrom / 10
    y_dim_nanometer = y_dim_angstrom / 10
    z_dim_nanometer = z_dim_angstrom / 10

    # Display the results in both nm and Å, including the input file type
    print(f"File Type: {file_type}")
    print(f"Dimensions of slab:")
    print(f"X = {x_dim_angstrom:.3f} Å = {x_dim_nanometer:.3f} nm")
    print(f"Y = {y_dim_angstrom:.3f} Å = {y_dim_nanometer:.3f} nm")
    print(f"Z = {z_dim_angstrom:.3f} Å = {z_dim_nanometer:.3f} nm")

# Run the script
if __name__ == "__main__":
    main()
# Out:
# File Type: GRO
# Dimensions of slab:
# X = 28.400 Å = 2.840 nm
# Y = 28.400 Å = 2.840 nm
# Z = 5.680 Å = 0.568 nm

# %% [markdown]
# ## THE NUMBER OF ATOMS

# %%
def count_atoms(file_path):
    # Get file extension to determine file format
    file_extension = file_path.split('.')[-1].lower()

    # Read the file and count atoms based on format
    with open(file_path, 'r') as file:
        lines = file.readlines()

    if file_extension == 'xyz':
        # .xyz files: The first line contains the number of atoms
        num_atoms = int(lines[0].strip())
    
    elif file_extension == 'pdb':
        # .pdb files: Count atoms by looking for "ATOM" or "HETATM" lines
        num_atoms = sum(1 for line in lines if line.startswith(('ATOM', 'HETATM')))
    
    elif file_extension == 'gro':
        # .gro files: The second line contains the number of atoms
        num_atoms = int(lines[1].strip().split()[0])
    
    else:
        raise ValueError("Unsupported file format. Only .xyz, .pdb, and .gro are supported.")
    
    return num_atoms

# Main function
def main():
    file_path = "md_setup/slab.gro"  # Replace with the path to your .xyz, .pdb, or .gro file
    try:
        num_atoms = count_atoms(file_path)
        print(f"Number of atoms in the file: {num_atoms}")
    except ValueError as e:
        print(e)

# Run the script
if __name__ == "__main__":
    main()
# Out:
# Number of atoms in the file: 563

# %% [markdown]
# ## SLAB ANALYSIS

# %% [markdown]
# - Making the comparison among coordinate files with different types of them.

# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# Function to analyze and visualize the slab structure
def analyze_slab_structure(file_path):
    if not os.path.isfile(file_path):
        print(f"Error: File {file_path} not found.")
        return None

    file_extension = os.path.splitext(file_path)[-1].lower()

    x_positions, y_positions, z_positions = [], [], []

    if file_extension == '.gro':
        with open(file_path, 'r') as file:
            lines = file.readlines()
        for line in lines[2:-1]:
            try:
                x_coord = float(line.split()[-3]) * 10  # Convert nm to Å
                y_coord = float(line.split()[-2]) * 10  # Convert nm to Å
                z_coord = float(line.split()[-1]) * 10  # Convert nm to Å
                x_positions.append(x_coord)
                y_positions.append(y_coord)
                z_positions.append(z_coord)
            except (ValueError, IndexError):
                continue

    elif file_extension == '.xyz':
        with open(file_path, 'r') as file:
            lines = file.readlines()[2:]
        for line in lines:
            try:
                _, x_coord, y_coord, z_coord = line.split()
                x_positions.append(float(x_coord))
                y_positions.append(float(y_coord))
                z_positions.append(float(z_coord))
            except (ValueError, IndexError):
                continue
    else:
        print("Unsupported file format. Please provide a .gro or .xyz file.")
        return None

    x_positions, y_positions, z_positions = map(np.array, [x_positions, y_positions, z_positions])

    # Slab thickness (Z-axis)
    z_min, z_max = z_positions.min(), z_positions.max()
    slab_thickness_angstrom = z_max - z_min

    # Length along X and Y axes
    x_min, x_max = x_positions.min(), x_positions.max()
    y_min, y_max = y_positions.min(), y_positions.max()
    length_x = x_max - x_min
    length_y = y_max - y_min

    # Total number of atoms
    total_atoms = len(x_positions)

    # Unique positions along X and Y axes
    unique_x_positions = len(np.unique(np.round(x_positions, 3)))
    unique_y_positions = len(np.unique(np.round(y_positions, 3)))

    # Results summary
    results = {
        "Slab Thickness (Å)": slab_thickness_angstrom,
        "Length in X-axis (Å)": length_x,
        "Length in Y-axis (Å)": length_y,
        "Total Number of Atoms": total_atoms,
        "Atoms Aligned on X-axis": unique_x_positions,
        "Atoms Aligned on Y-axis": unique_y_positions,
    }

    return results

# Compare results from GRO and XYZ files
def compare_structures(gro_file, xyz_file):
    gro_results = analyze_slab_structure(gro_file)
    xyz_results = analyze_slab_structure(xyz_file)

    if not gro_results or not xyz_results:
        print("Error in analyzing one or both files.")
        return

    print("\nComparison of GRO and XYZ Files:")
    for key in gro_results:
        print(f"{key}:")
        print(f"  GRO: {gro_results[key]}")
        print(f"  XYZ: {xyz_results[key]}")
        if isinstance(gro_results[key], (int, float)):
            print(f"  Difference: {abs(gro_results[key] - xyz_results[key])}")
        else:
            print("  Difference: N/A")

# Paths to the GRO and XYZ files
gro_file = r"/home/usac/Desktop/newsitt/thesis/md_setup/slab.gro"
xyz_file = r"/home/usac/Desktop/newsitt/thesis/md_setup/slab.xyz"

# Run comparison
compare_structures(gro_file, xyz_file)
# Out:
# Comparison of GRO and XYZ Files:
# Slab Thickness (Å):
#   GRO: 5.68
#   XYZ: 5.680103
#   Difference: 0.00010300000000018628
# Length in X-axis (Å):
#   GRO: 28.4
#   XYZ: 28.400517
#   Difference: 0.0005170000000020991
# Length in Y-axis (Å):
#   GRO: 28.4
#   XYZ: 28.400517
#   Difference: 0.0005170000000020991
# Total Number of Atoms:
#   GRO: 563
#   XYZ: 563
#   Difference: 0
# Atoms Aligned on X-axis:
#   GRO: 21
#   XYZ: 21
#   Difference: 0
# Atoms Aligned on Y-axis:
#   GRO: 21
#   XYZ: 21
#   Difference: 0

# %% [markdown]
# # SLAB IN THE BOX

# %% [markdown]
# ### REFORMAT GRO FILE

# %%
def reformat_gro_file(input_file, output_file):
    try:
        with open(input_file, "r") as file:
            lines = file.readlines()

        fixed_lines = []

        # Copy header and atom count lines
        fixed_lines.append(lines[0].strip() + "\n")
        atom_count = int(lines[1].strip())
        fixed_lines.append(f"{atom_count}\n")

        # Reformat atom lines
        for i, line in enumerate(lines[2:-1]):  # Exclude header and box lines
            try:
                # Parse fields assuming possible formatting issues
                resid = int(line[:5].strip())  # Residue number
                resname = line[5:10].strip()  # Residue name
                atomname = line[10:15].strip()  # Atom name
                atomnum = int(line[15:20].strip())  # Atom index
                x = float(line[20:28].strip())  # X-coordinate
                y = float(line[28:36].strip())  # Y-coordinate
                z = float(line[36:44].strip())  # Z-coordinate

                # Reformat line into proper .gro format
                fixed_line = f"{resid:>5}{resname:<5}{atomname:<5}{atomnum:>5}{x:8.3f}{y:8.3f}{z:8.3f}\n"
                fixed_lines.append(fixed_line)
            except ValueError:
                print(f"Skipping malformed line {i + 3}: {line.strip()}")

        # Append the box dimensions
        box_line = lines[-1].strip()
        fixed_lines.append(box_line + "\n")

        # Write the fixed .gro file
        with open(output_file, "w") as outfile:
            outfile.writelines(fixed_lines)

        print(f"Reformatted .gro file written to: {output_file}")

    except Exception as e:
        print(f"Error during reformatting: {e}")


# Specify input and output file paths
input_gro_file = "md_setup/box.gro"  # Replace with your input file
output_gro_file = "md_setup/fixed_box.gro"  # Corrected output file

# Run the function
reformat_gro_file(input_gro_file, output_gro_file)
# Out:
# Reformatted .gro file written to: md_setup/fixed_box.gro

# %%
def validate_gro_file(input_file):
    try:
        with open(input_file, "r") as file:
            lines = file.readlines()

        print(f"Validating GRO file: {input_file}")

        errors = []  # To collect all errors
        residues = set()  # To collect unique residues

        # 1. Check Header
        if len(lines) < 3:
            errors.append("The file does not contain enough lines to be a valid .gro file.")
            return False

        header = lines[0].strip()
        if not header:
            errors.append("Missing header line.")
        else:
            print(f"Header: {header}")

        # 2. Check Atom Count Line
        try:
            atom_count = int(lines[1].strip())
            print(f"Declared Atom Count: {atom_count}")
        except ValueError:
            errors.append("The second line (atom count) is not a valid integer.")
            atom_count = None

        # 3. Check Atom Lines
        atom_lines = lines[2:-1]
        if atom_count is not None and len(atom_lines) != atom_count:
            errors.append(
                f"Atom count mismatch: Declared atom count ({atom_count}) "
                f"does not match the number of atom lines ({len(atom_lines)})."
            )

        for i, line in enumerate(atom_lines):
            if len(line.strip()) < 44:
                errors.append(f"Atom line {i + 3} is too short: {line.strip()}")
                continue
            try:
                resid = int(line[:5].strip())
                resname = line[5:10].strip()
                atomname = line[10:15].strip()
                atomnum = int(line[15:20].strip())
                x = float(line[20:28].strip())
                y = float(line[28:36].strip())
                z = float(line[36:44].strip())

                # Add residue to the set
                residues.add(resname)
            except ValueError as e:
                errors.append(f"Atom line {i + 3} is incorrectly formatted: {line.strip()} | Error: {e}")

        if not errors:
            print("All atom lines are correctly formatted.")
        else:
            print(f"Found {len(errors)} issues in atom lines.")

        # Display unique residues
        print(f"Residues found in the GRO file: {', '.join(sorted(residues))}")

        # 4. Check Box Dimensions
        box_line = lines[-1].strip()
        box_values = box_line.split()
        if len(box_values) not in [3, 9]:
            errors.append(f"Box dimensions line is invalid: {box_line}")
        else:
            try:
                box_values = [float(v) for v in box_values]
                print("Box dimensions are valid.")
            except ValueError:
                errors.append(f"Box dimensions line contains non-numeric values: {box_line}")

        # Print all errors
        if errors:
            print("\n### Errors Found in the GRO File ###")
            for error in errors:
                print(f"- {error}")
            return False

        print("\nGRO file format is correct.")
        return True

    except Exception as e:
        print(f"Error during validation: {e}")
        return False


# Specify input file
input_gro_file = "/mnt/newsitt/topic1/slab/slab_bottom.gro"  # Replace with your input .gro file

# Validate the .gro file
is_valid = validate_gro_file(input_gro_file)
if not is_valid:
    print("The GRO file is invalid. Please fix the reported issues.")
else:
    print("The GRO file is valid.")
# Out:
# Validating GRO file: /mnt/newsitt/topic1/slab/slab_bottom.gro
# Header: ADSORPTION STUDIES OF CATIONIC SURFACTANTS
# Declared Atom Count: 563
# Found 563 issues in atom lines.
# Residues found in the GRO file:
# Box dimensions are valid.
#
# ### Errors Found in the GRO File ###
# - Atom line 3 is too short: 0FE     Fe    1   0.080   0.080   0.000
# - Atom line 4 is too short: 0FE     Fe    2   0.080   0.080   0.284
# - Atom line 5 is too short: 0FE     Fe    3   0.080   0.080   0.568
# - Atom line 6 is too short: 0FE     Fe    4   0.080   0.364   0.000
# - Atom line 7 is too short: 0FE     Fe    5   0.080   0.364   0.284
# - Atom line 8 is too short: 0FE     Fe    6   0.222   0.222   0.142
# - Atom line 9 is too short: 0FE     Fe    7   0.080   0.364   0.568
# - Atom line 10 is too short: 0FE     Fe    8   0.222   0.222   0.426
# - Atom line 11 is too short: 0FE     Fe    9   0.080   0.648   0.000
# - Atom line 12 is too short: 0FE     Fe   10   0.080   0.648   0.284
# - Atom line 13 is too short: 0FE     Fe   11   0.222   0.506   0.142
# - Atom line 14 is too short: 0FE     Fe   12   0.080   0.648   0.568
# - Atom line 15 is too short: 0FE     Fe   13   0.222   0.506   0.426
# - Atom line 16 is too short: 0FE     Fe   14   0.080   0.932   0.000
# - Atom line 17 is too short: 0FE     Fe   15   0.080   0.932   0.284
# - Atom line 18 is too short: 0FE     Fe   16   0.222   0.790   0.142
# - Atom line 19 is too short: 0FE     Fe   17   0.080   0.932   0.568
# - Atom line 20 is too short: 0FE     Fe   18   0.222   0.790   0.426
# - Atom line 21 is too short: 0FE     Fe   19   0.080   1.216   0.000
# - Atom line 22 is too short: 0FE     Fe   20   0.080   1.216   0.284
# - Atom line 23 is too short: 0FE     Fe   21   0.222   1.074   0.142
# - Atom line 24 is too short: 0FE     Fe   22   0.080   1.216   0.568
# - Atom line 25 is too short: 0FE     Fe   23   0.222   1.074   0.426
# - Atom line 26 is too short: 0FE     Fe   24   0.080   1.500   0.000
# - Atom line 27 is too short: 0FE     Fe   25   0.080   1.500   0.284
# - Atom line 28 is too short: 0FE     Fe   26   0.222   1.358   0.142
# - Atom line 29 is too short: 0FE     Fe   27   0.080   1.500   0.568
# - Atom line 30 is too short: 0FE     Fe   28   0.222   1.358   0.426
# - Atom line 31 is too short: 0FE     Fe   29   0.080   1.784   0.000
# - Atom line 32 is too short: 0FE     Fe   30   0.080   1.784   0.284
# - Atom line 33 is too short: 0FE     Fe   31   0.222   1.642   0.142
# - Atom line 34 is too short: 0FE     Fe   32   0.080   1.784   0.568
# - Atom line 35 is too short: 0FE     Fe   33   0.222   1.642   0.426
# - Atom line 36 is too short: 0FE     Fe   34   0.080   2.068   0.000
# - Atom line 37 is too short: 0FE     Fe   35   0.080   2.068   0.284
# - Atom line 38 is too short: 0FE     Fe   36   0.222   1.926   0.142
# - Atom line 39 is too short: 0FE     Fe   37   0.080   2.068   0.568
# - Atom line 40 is too short: 0FE     Fe   38   0.222   1.926   0.426
# - Atom line 41 is too short: 0FE     Fe   39   0.080   2.352   0.000
# - Atom line 42 is too short: 0FE     Fe   40   0.080   2.352   0.284
# - Atom line 43 is too short: 0FE     Fe   41   0.222   2.210   0.142
# - Atom line 44 is too short: 0FE     Fe   42   0.080   2.352   0.568
# - Atom line 45 is too short: 0FE     Fe   43   0.222   2.210   0.426
# - Atom line 46 is too short: 0FE     Fe   44   0.080   2.636   0.000
# - Atom line 47 is too short: 0FE     Fe   45   0.080   2.636   0.284
# - Atom line 48 is too short: 0FE     Fe   46   0.222   2.494   0.142
# - Atom line 49 is too short: 0FE     Fe   47   0.080   2.636   0.568
# - Atom line 50 is too short: 0FE     Fe   48   0.222   2.494   0.426
# - Atom line 51 is too short: 0FE     Fe   49   0.080   2.920   0.000
# - Atom line 52 is too short: 0FE     Fe   50   0.080   2.920   0.284
# - Atom line 53 is too short: 0FE     Fe   51   0.222   2.778   0.142
# - Atom line 54 is too short: 0FE     Fe   52   0.080   2.920   0.568
# - Atom line 55 is too short: 0FE     Fe   53   0.222   2.778   0.426
# - Atom line 56 is too short: 0FE     Fe   54   0.364   0.080   0.000
# - Atom line 57 is too short: 0FE     Fe   55   0.364   0.080   0.284
# - Atom line 58 is too short: 0FE     Fe   56   0.364   0.080   0.568
# - Atom line 59 is too short: 0FE     Fe   57   0.364   0.364   0.000
# - Atom line 60 is too short: 0FE     Fe   58   0.364   0.364   0.284
# - Atom line 61 is too short: 0FE     Fe   59   0.506   0.222   0.142
# - Atom line 62 is too short: 0FE     Fe   60   0.364   0.364   0.568
# - Atom line 63 is too short: 0FE     Fe   61   0.506   0.222   0.426
# - Atom line 64 is too short: 0FE     Fe   62   0.364   0.648   0.000
# - Atom line 65 is too short: 0FE     Fe   63   0.364   0.648   0.284
# - Atom line 66 is too short: 0FE     Fe   64   0.506   0.506   0.142
# - Atom line 67 is too short: 0FE     Fe   65   0.364   0.648   0.568
# - Atom line 68 is too short: 0FE     Fe   66   0.506   0.506   0.426
# - Atom line 69 is too short: 0FE     Fe   67   0.364   0.932   0.000
# - Atom line 70 is too short: 0FE     Fe   68   0.364   0.932   0.284
# - Atom line 71 is too short: 0FE     Fe   69   0.506   0.790   0.142
# - Atom line 72 is too short: 0FE     Fe   70   0.364   0.932   0.568
# - Atom line 73 is too short: 0FE     Fe   71   0.506   0.790   0.426
# - Atom line 74 is too short: 0FE     Fe   72   0.364   1.216   0.000
# - Atom line 75 is too short: 0FE     Fe   73   0.364   1.216   0.284
# - Atom line 76 is too short: 0FE     Fe   74   0.506   1.074   0.142
# - Atom line 77 is too short: 0FE     Fe   75   0.364   1.216   0.568
# - Atom line 78 is too short: 0FE     Fe   76   0.506   1.074   0.426
# - Atom line 79 is too short: 0FE     Fe   77   0.364   1.500   0.000
# - Atom line 80 is too short: 0FE     Fe   78   0.364   1.500   0.284
# - Atom line 81 is too short: 0FE     Fe   79   0.506   1.358   0.142
# - Atom line 82 is too short: 0FE     Fe   80   0.364   1.500   0.568
# - Atom line 83 is too short: 0FE     Fe   81   0.506   1.358   0.426
# - Atom line 84 is too short: 0FE     Fe   82   0.364   1.784   0.000
# - Atom line 85 is too short: 0FE     Fe   83   0.364   1.784   0.284
# - Atom line 86 is too short: 0FE     Fe   84   0.506   1.642   0.142
# - Atom line 87 is too short: 0FE     Fe   85   0.364   1.784   0.568
# - Atom line 88 is too short: 0FE     Fe   86   0.506   1.642   0.426
# - Atom line 89 is too short: 0FE     Fe   87   0.364   2.068   0.000
# - Atom line 90 is too short: 0FE     Fe   88   0.364   2.068   0.284
# - Atom line 91 is too short: 0FE     Fe   89   0.506   1.926   0.142
# - Atom line 92 is too short: 0FE     Fe   90   0.364   2.068   0.568
# - Atom line 93 is too short: 0FE     Fe   91   0.506   1.926   0.426
# - Atom line 94 is too short: 0FE     Fe   92   0.364   2.352   0.000
# - Atom line 95 is too short: 0FE     Fe   93   0.364   2.352   0.284
# - Atom line 96 is too short: 0FE     Fe   94   0.506   2.210   0.142
# - Atom line 97 is too short: 0FE     Fe   95   0.364   2.352   0.568
# - Atom line 98 is too short: 0FE     Fe   96   0.506   2.210   0.426
# - Atom line 99 is too short: 0FE     Fe   97   0.364   2.636   0.000
# - Atom line 100 is too short: 0FE     Fe   98   0.364   2.636   0.284
# - Atom line 101 is too short: 0FE     Fe   99   0.506   2.494   0.142
# - Atom line 102 is too short: 0FE     Fe  100   0.364   2.636   0.568
# - Atom line 103 is too short: 0FE     Fe  101   0.506   2.494   0.426
# - Atom line 104 is too short: 0FE     Fe  102   0.364   2.920   0.000
# - Atom line 105 is too short: 0FE     Fe  103   0.364   2.920   0.284
# - Atom line 106 is too short: 0FE     Fe  104   0.506   2.778   0.142
# - Atom line 107 is too short: 0FE     Fe  105   0.364   2.920   0.568
# - Atom line 108 is too short: 0FE     Fe  106   0.506   2.778   0.426
# - Atom line 109 is too short: 0FE     Fe  107   0.648   0.080   0.000
# - Atom line 110 is too short: 0FE     Fe  108   0.648   0.080   0.284
# - Atom line 111 is too short: 0FE     Fe  109   0.648   0.080   0.568
# - Atom line 112 is too short: 0FE     Fe  110   0.648   0.364   0.000
# - Atom line 113 is too short: 0FE     Fe  111   0.648   0.364   0.284
# - Atom line 114 is too short: 0FE     Fe  112   0.790   0.222   0.142
# - Atom line 115 is too short: 0FE     Fe  113   0.648   0.364   0.568
# - Atom line 116 is too short: 0FE     Fe  114   0.790   0.222   0.426
# - Atom line 117 is too short: 0FE     Fe  115   0.648   0.648   0.000
# - Atom line 118 is too short: 0FE     Fe  116   0.648   0.648   0.284
# - Atom line 119 is too short: 0FE     Fe  117   0.790   0.506   0.142
# - Atom line 120 is too short: 0FE     Fe  118   0.648   0.648   0.568
# - Atom line 121 is too short: 0FE     Fe  119   0.790   0.506   0.426
# - Atom line 122 is too short: 0FE     Fe  120   0.648   0.932   0.000
# - Atom line 123 is too short: 0FE     Fe  121   0.648   0.932   0.284
# - Atom line 124 is too short: 0FE     Fe  122   0.790   0.790   0.142
# - Atom line 125 is too short: 0FE     Fe  123   0.648   0.932   0.568
# - Atom line 126 is too short: 0FE     Fe  124   0.790   0.790   0.426
# - Atom line 127 is too short: 0FE     Fe  125   0.648   1.216   0.000
# - Atom line 128 is too short: 0FE     Fe  126   0.648   1.216   0.284
# - Atom line 129 is too short: 0FE     Fe  127   0.790   1.074   0.142
# - Atom line 130 is too short: 0FE     Fe  128   0.648   1.216   0.568
# - Atom line 131 is too short: 0FE     Fe  129   0.790   1.074   0.426
# - Atom line 132 is too short: 0FE     Fe  130   0.648   1.500   0.000
# - Atom line 133 is too short: 0FE     Fe  131   0.648   1.500   0.284
# - Atom line 134 is too short: 0FE     Fe  132   0.790   1.358   0.142
# - Atom line 135 is too short: 0FE     Fe  133   0.648   1.500   0.568
# - Atom line 136 is too short: 0FE     Fe  134   0.790   1.358   0.426
# - Atom line 137 is too short: 0FE     Fe  135   0.648   1.784   0.000
# - Atom line 138 is too short: 0FE     Fe  136   0.648   1.784   0.284
# - Atom line 139 is too short: 0FE     Fe  137   0.790   1.642   0.142
# - Atom line 140 is too short: 0FE     Fe  138   0.648   1.784   0.568
# - Atom line 141 is too short: 0FE     Fe  139   0.790   1.642   0.426
# - Atom line 142 is too short: 0FE     Fe  140   0.648   2.068   0.000
# - Atom line 143 is too short: 0FE     Fe  141   0.648   2.068   0.284
# - Atom line 144 is too short: 0FE     Fe  142   0.790   1.926   0.142
# - Atom line 145 is too short: 0FE     Fe  143   0.648   2.068   0.568
# - Atom line 146 is too short: 0FE     Fe  144   0.790   1.926   0.426
# - Atom line 147 is too short: 0FE     Fe  145   0.648   2.352   0.000
# - Atom line 148 is too short: 0FE     Fe  146   0.648   2.352   0.284
# - Atom line 149 is too short: 0FE     Fe  147   0.790   2.210   0.142
# - Atom line 150 is too short: 0FE     Fe  148   0.648   2.352   0.568
# - Atom line 151 is too short: 0FE     Fe  149   0.790   2.210   0.426
# - Atom line 152 is too short: 0FE     Fe  150   0.648   2.636   0.000
# - Atom line 153 is too short: 0FE     Fe  151   0.648   2.636   0.284
# - Atom line 154 is too short: 0FE     Fe  152   0.790   2.494   0.142
# - Atom line 155 is too short: 0FE     Fe  153   0.648   2.636   0.568
# - Atom line 156 is too short: 0FE     Fe  154   0.790   2.494   0.426
# - Atom line 157 is too short: 0FE     Fe  155   0.648   2.920   0.000
# - Atom line 158 is too short: 0FE     Fe  156   0.648   2.920   0.284
# - Atom line 159 is too short: 0FE     Fe  157   0.790   2.778   0.142
# - Atom line 160 is too short: 0FE     Fe  158   0.648   2.920   0.568
# - Atom line 161 is too short: 0FE     Fe  159   0.790   2.778   0.426
# - Atom line 162 is too short: 0FE     Fe  160   0.932   0.080   0.000
# - Atom line 163 is too short: 0FE     Fe  161   0.932   0.080   0.284
# - Atom line 164 is too short: 0FE     Fe  162   0.932   0.080   0.568
# - Atom line 165 is too short: 0FE     Fe  163   0.932   0.364   0.000
# - Atom line 166 is too short: 0FE     Fe  164   0.932   0.364   0.284
# - Atom line 167 is too short: 0FE     Fe  165   1.074   0.222   0.142
# - Atom line 168 is too short: 0FE     Fe  166   0.932   0.364   0.568
# - Atom line 169 is too short: 0FE     Fe  167   1.074   0.222   0.426
# - Atom line 170 is too short: 0FE     Fe  168   0.932   0.648   0.000
# - Atom line 171 is too short: 0FE     Fe  169   0.932   0.648   0.284
# - Atom line 172 is too short: 0FE     Fe  170   1.074   0.506   0.142
# - Atom line 173 is too short: 0FE     Fe  171   0.932   0.648   0.568
# - Atom line 174 is too short: 0FE     Fe  172   1.074   0.506   0.426
# - Atom line 175 is too short: 0FE     Fe  173   0.932   0.932   0.000
# - Atom line 176 is too short: 0FE     Fe  174   0.932   0.932   0.284
# - Atom line 177 is too short: 0FE     Fe  175   1.074   0.790   0.142
# - Atom line 178 is too short: 0FE     Fe  176   0.932   0.932   0.568
# - Atom line 179 is too short: 0FE     Fe  177   1.074   0.790   0.426
# - Atom line 180 is too short: 0FE     Fe  178   0.932   1.216   0.000
# - Atom line 181 is too short: 0FE     Fe  179   0.932   1.216   0.284
# - Atom line 182 is too short: 0FE     Fe  180   1.074   1.074   0.142
# - Atom line 183 is too short: 0FE     Fe  181   0.932   1.216   0.568
# - Atom line 184 is too short: 0FE     Fe  182   1.074   1.074   0.426
# - Atom line 185 is too short: 0FE     Fe  183   0.932   1.500   0.000
# - Atom line 186 is too short: 0FE     Fe  184   0.932   1.500   0.284
# - Atom line 187 is too short: 0FE     Fe  185   1.074   1.358   0.142
# - Atom line 188 is too short: 0FE     Fe  186   0.932   1.500   0.568
# - Atom line 189 is too short: 0FE     Fe  187   1.074   1.358   0.426
# - Atom line 190 is too short: 0FE     Fe  188   0.932   1.784   0.000
# - Atom line 191 is too short: 0FE     Fe  189   0.932   1.784   0.284
# - Atom line 192 is too short: 0FE     Fe  190   1.074   1.642   0.142
# - Atom line 193 is too short: 0FE     Fe  191   0.932   1.784   0.568
# - Atom line 194 is too short: 0FE     Fe  192   1.074   1.642   0.426
# - Atom line 195 is too short: 0FE     Fe  193   0.932   2.068   0.000
# - Atom line 196 is too short: 0FE     Fe  194   0.932   2.068   0.284
# - Atom line 197 is too short: 0FE     Fe  195   1.074   1.926   0.142
# - Atom line 198 is too short: 0FE     Fe  196   0.932   2.068   0.568
# - Atom line 199 is too short: 0FE     Fe  197   1.074   1.926   0.426
# - Atom line 200 is too short: 0FE     Fe  198   0.932   2.352   0.000
# - Atom line 201 is too short: 0FE     Fe  199   0.932   2.352   0.284
# - Atom line 202 is too short: 0FE     Fe  200   1.074   2.210   0.142
# - Atom line 203 is too short: 0FE     Fe  201   0.932   2.352   0.568
# - Atom line 204 is too short: 0FE     Fe  202   1.074   2.210   0.426
# - Atom line 205 is too short: 0FE     Fe  203   0.932   2.636   0.000
# - Atom line 206 is too short: 0FE     Fe  204   0.932   2.636   0.284
# - Atom line 207 is too short: 0FE     Fe  205   1.074   2.494   0.142
# - Atom line 208 is too short: 0FE     Fe  206   0.932   2.636   0.568
# - Atom line 209 is too short: 0FE     Fe  207   1.074   2.494   0.426
# - Atom line 210 is too short: 0FE     Fe  208   0.932   2.920   0.000
# - Atom line 211 is too short: 0FE     Fe  209   0.932   2.920   0.284
# - Atom line 212 is too short: 0FE     Fe  210   1.074   2.778   0.142
# - Atom line 213 is too short: 0FE     Fe  211   0.932   2.920   0.568
# - Atom line 214 is too short: 0FE     Fe  212   1.074   2.778   0.426
# - Atom line 215 is too short: 0FE     Fe  213   1.216   0.080   0.000
# - Atom line 216 is too short: 0FE     Fe  214   1.216   0.080   0.284
# - Atom line 217 is too short: 0FE     Fe  215   1.216   0.080   0.568
# - Atom line 218 is too short: 0FE     Fe  216   1.216   0.364   0.000
# - Atom line 219 is too short: 0FE     Fe  217   1.216   0.364   0.284
# - Atom line 220 is too short: 0FE     Fe  218   1.358   0.222   0.142
# - Atom line 221 is too short: 0FE     Fe  219   1.216   0.364   0.568
# - Atom line 222 is too short: 0FE     Fe  220   1.358   0.222   0.426
# - Atom line 223 is too short: 0FE     Fe  221   1.216   0.648   0.000
# - Atom line 224 is too short: 0FE     Fe  222   1.216   0.648   0.284
# - Atom line 225 is too short: 0FE     Fe  223   1.358   0.506   0.142
# - Atom line 226 is too short: 0FE     Fe  224   1.216   0.648   0.568
# - Atom line 227 is too short: 0FE     Fe  225   1.358   0.506   0.426
# - Atom line 228 is too short: 0FE     Fe  226   1.216   0.932   0.000
# - Atom line 229 is too short: 0FE     Fe  227   1.216   0.932   0.284
# - Atom line 230 is too short: 0FE     Fe  228   1.358   0.790   0.142
# - Atom line 231 is too short: 0FE     Fe  229   1.216   0.932   0.568
# - Atom line 232 is too short: 0FE     Fe  230   1.358   0.790   0.426
# - Atom line 233 is too short: 0FE     Fe  231   1.216   1.216   0.000
# - Atom line 234 is too short: 0FE     Fe  232   1.216   1.216   0.284
# - Atom line 235 is too short: 0FE     Fe  233   1.358   1.074   0.142
# - Atom line 236 is too short: 0FE     Fe  234   1.216   1.216   0.568
# - Atom line 237 is too short: 0FE     Fe  235   1.358   1.074   0.426
# - Atom line 238 is too short: 0FE     Fe  236   1.216   1.500   0.000
# - Atom line 239 is too short: 0FE     Fe  237   1.216   1.500   0.284
# - Atom line 240 is too short: 0FE     Fe  238   1.358   1.358   0.142
# - Atom line 241 is too short: 0FE     Fe  239   1.216   1.500   0.568
# - Atom line 242 is too short: 0FE     Fe  240   1.358   1.358   0.426
# - Atom line 243 is too short: 0FE     Fe  241   1.216   1.784   0.000
# - Atom line 244 is too short: 0FE     Fe  242   1.216   1.784   0.284
# - Atom line 245 is too short: 0FE     Fe  243   1.358   1.642   0.142
# - Atom line 246 is too short: 0FE     Fe  244   1.216   1.784   0.568
# - Atom line 247 is too short: 0FE     Fe  245   1.358   1.642   0.426
# - Atom line 248 is too short: 0FE     Fe  246   1.216   2.068   0.000
# - Atom line 249 is too short: 0FE     Fe  247   1.216   2.068   0.284
# - Atom line 250 is too short: 0FE     Fe  248   1.358   1.926   0.142
# - Atom line 251 is too short: 0FE     Fe  249   1.216   2.068   0.568
# - Atom line 252 is too short: 0FE     Fe  250   1.358   1.926   0.426
# - Atom line 253 is too short: 0FE     Fe  251   1.216   2.352   0.000
# - Atom line 254 is too short: 0FE     Fe  252   1.216   2.352   0.284
# - Atom line 255 is too short: 0FE     Fe  253   1.358   2.210   0.142
# - Atom line 256 is too short: 0FE     Fe  254   1.216   2.352   0.568
# - Atom line 257 is too short: 0FE     Fe  255   1.358   2.210   0.426
# - Atom line 258 is too short: 0FE     Fe  256   1.216   2.636   0.000
# - Atom line 259 is too short: 0FE     Fe  257   1.216   2.636   0.284
# - Atom line 260 is too short: 0FE     Fe  258   1.358   2.494   0.142
# - Atom line 261 is too short: 0FE     Fe  259   1.216   2.636   0.568
# - Atom line 262 is too short: 0FE     Fe  260   1.358   2.494   0.426
# - Atom line 263 is too short: 0FE     Fe  261   1.216   2.920   0.000
# - Atom line 264 is too short: 0FE     Fe  262   1.216   2.920   0.284
# - Atom line 265 is too short: 0FE     Fe  263   1.358   2.778   0.142
# - Atom line 266 is too short: 0FE     Fe  264   1.216   2.920   0.568
# - Atom line 267 is too short: 0FE     Fe  265   1.358   2.778   0.426
# - Atom line 268 is too short: 0FE     Fe  266   1.500   0.080   0.000
# - Atom line 269 is too short: 0FE     Fe  267   1.500   0.080   0.284
# - Atom line 270 is too short: 0FE     Fe  268   1.500   0.080   0.568
# - Atom line 271 is too short: 0FE     Fe  269   1.500   0.364   0.000
# - Atom line 272 is too short: 0FE     Fe  270   1.500   0.364   0.284
# - Atom line 273 is too short: 0FE     Fe  271   1.642   0.222   0.142
# - Atom line 274 is too short: 0FE     Fe  272   1.500   0.364   0.568
# - Atom line 275 is too short: 0FE     Fe  273   1.642   0.222   0.426
# - Atom line 276 is too short: 0FE     Fe  274   1.500   0.648   0.000
# - Atom line 277 is too short: 0FE     Fe  275   1.500   0.648   0.284
# - Atom line 278 is too short: 0FE     Fe  276   1.642   0.506   0.142
# - Atom line 279 is too short: 0FE     Fe  277   1.500   0.648   0.568
# - Atom line 280 is too short: 0FE     Fe  278   1.642   0.506   0.426
# - Atom line 281 is too short: 0FE     Fe  279   1.500   0.932   0.000
# - Atom line 282 is too short: 0FE     Fe  280   1.500   0.932   0.284
# - Atom line 283 is too short: 0FE     Fe  281   1.642   0.790   0.142
# - Atom line 284 is too short: 0FE     Fe  282   1.500   0.932   0.568
# - Atom line 285 is too short: 0FE     Fe  283   1.642   0.790   0.426
# - Atom line 286 is too short: 0FE     Fe  284   1.500   1.216   0.000
# - Atom line 287 is too short: 0FE     Fe  285   1.500   1.216   0.284
# - Atom line 288 is too short: 0FE     Fe  286   1.642   1.074   0.142
# - Atom line 289 is too short: 0FE     Fe  287   1.500   1.216   0.568
# - Atom line 290 is too short: 0FE     Fe  288   1.642   1.074   0.426
# - Atom line 291 is too short: 0FE     Fe  289   1.500   1.500   0.000
# - Atom line 292 is too short: 0FE     Fe  290   1.500   1.500   0.284
# - Atom line 293 is too short: 0FE     Fe  291   1.642   1.358   0.142
# - Atom line 294 is too short: 0FE     Fe  292   1.500   1.500   0.568
# - Atom line 295 is too short: 0FE     Fe  293   1.642   1.358   0.426
# - Atom line 296 is too short: 0FE     Fe  294   1.500   1.784   0.000
# - Atom line 297 is too short: 0FE     Fe  295   1.500   1.784   0.284
# - Atom line 298 is too short: 0FE     Fe  296   1.642   1.642   0.142
# - Atom line 299 is too short: 0FE     Fe  297   1.500   1.784   0.568
# - Atom line 300 is too short: 0FE     Fe  298   1.642   1.642   0.426
# - Atom line 301 is too short: 0FE     Fe  299   1.500   2.068   0.000
# - Atom line 302 is too short: 0FE     Fe  300   1.500   2.068   0.284
# - Atom line 303 is too short: 0FE     Fe  301   1.642   1.926   0.142
# - Atom line 304 is too short: 0FE     Fe  302   1.500   2.068   0.568
# - Atom line 305 is too short: 0FE     Fe  303   1.642   1.926   0.426
# - Atom line 306 is too short: 0FE     Fe  304   1.500   2.352   0.000
# - Atom line 307 is too short: 0FE     Fe  305   1.500   2.352   0.284
# - Atom line 308 is too short: 0FE     Fe  306   1.642   2.210   0.142
# - Atom line 309 is too short: 0FE     Fe  307   1.500   2.352   0.568
# - Atom line 310 is too short: 0FE     Fe  308   1.642   2.210   0.426
# - Atom line 311 is too short: 0FE     Fe  309   1.500   2.636   0.000
# - Atom line 312 is too short: 0FE     Fe  310   1.500   2.636   0.284
# - Atom line 313 is too short: 0FE     Fe  311   1.642   2.494   0.142
# - Atom line 314 is too short: 0FE     Fe  312   1.500   2.636   0.568
# - Atom line 315 is too short: 0FE     Fe  313   1.642   2.494   0.426
# - Atom line 316 is too short: 0FE     Fe  314   1.500   2.920   0.000
# - Atom line 317 is too short: 0FE     Fe  315   1.500   2.920   0.284
# - Atom line 318 is too short: 0FE     Fe  316   1.642   2.778   0.142
# - Atom line 319 is too short: 0FE     Fe  317   1.500   2.920   0.568
# - Atom line 320 is too short: 0FE     Fe  318   1.642   2.778   0.426
# - Atom line 321 is too short: 0FE     Fe  319   1.784   0.080   0.000
# - Atom line 322 is too short: 0FE     Fe  320   1.784   0.080   0.284
# - Atom line 323 is too short: 0FE     Fe  321   1.784   0.080   0.568
# - Atom line 324 is too short: 0FE     Fe  322   1.784   0.364   0.000
# - Atom line 325 is too short: 0FE     Fe  323   1.784   0.364   0.284
# - Atom line 326 is too short: 0FE     Fe  324   1.926   0.222   0.142
# - Atom line 327 is too short: 0FE     Fe  325   1.784   0.364   0.568
# - Atom line 328 is too short: 0FE     Fe  326   1.926   0.222   0.426
# - Atom line 329 is too short: 0FE     Fe  327   1.784   0.648   0.000
# - Atom line 330 is too short: 0FE     Fe  328   1.784   0.648   0.284
# - Atom line 331 is too short: 0FE     Fe  329   1.926   0.506   0.142
# - Atom line 332 is too short: 0FE     Fe  330   1.784   0.648   0.568
# - Atom line 333 is too short: 0FE     Fe  331   1.926   0.506   0.426
# - Atom line 334 is too short: 0FE     Fe  332   1.784   0.932   0.000
# - Atom line 335 is too short: 0FE     Fe  333   1.784   0.932   0.284
# - Atom line 336 is too short: 0FE     Fe  334   1.926   0.790   0.142
# - Atom line 337 is too short: 0FE     Fe  335   1.784   0.932   0.568
# - Atom line 338 is too short: 0FE     Fe  336   1.926   0.790   0.426
# - Atom line 339 is too short: 0FE     Fe  337   1.784   1.216   0.000
# - Atom line 340 is too short: 0FE     Fe  338   1.784   1.216   0.284
# - Atom line 341 is too short: 0FE     Fe  339   1.926   1.074   0.142
# - Atom line 342 is too short: 0FE     Fe  340   1.784   1.216   0.568
# - Atom line 343 is too short: 0FE     Fe  341   1.926   1.074   0.426
# - Atom line 344 is too short: 0FE     Fe  342   1.784   1.500   0.000
# - Atom line 345 is too short: 0FE     Fe  343   1.784   1.500   0.284
# - Atom line 346 is too short: 0FE     Fe  344   1.926   1.358   0.142
# - Atom line 347 is too short: 0FE     Fe  345   1.784   1.500   0.568
# - Atom line 348 is too short: 0FE     Fe  346   1.926   1.358   0.426
# - Atom line 349 is too short: 0FE     Fe  347   1.784   1.784   0.000
# - Atom line 350 is too short: 0FE     Fe  348   1.784   1.784   0.284
# - Atom line 351 is too short: 0FE     Fe  349   1.926   1.642   0.142
# - Atom line 352 is too short: 0FE     Fe  350   1.784   1.784   0.568
# - Atom line 353 is too short: 0FE     Fe  351   1.926   1.642   0.426
# - Atom line 354 is too short: 0FE     Fe  352   1.784   2.068   0.000
# - Atom line 355 is too short: 0FE     Fe  353   1.784   2.068   0.284
# - Atom line 356 is too short: 0FE     Fe  354   1.926   1.926   0.142
# - Atom line 357 is too short: 0FE     Fe  355   1.784   2.068   0.568
# - Atom line 358 is too short: 0FE     Fe  356   1.926   1.926   0.426
# - Atom line 359 is too short: 0FE     Fe  357   1.784   2.352   0.000
# - Atom line 360 is too short: 0FE     Fe  358   1.784   2.352   0.284
# - Atom line 361 is too short: 0FE     Fe  359   1.926   2.210   0.142
# - Atom line 362 is too short: 0FE     Fe  360   1.784   2.352   0.568
# - Atom line 363 is too short: 0FE     Fe  361   1.926   2.210   0.426
# - Atom line 364 is too short: 0FE     Fe  362   1.784   2.636   0.000
# - Atom line 365 is too short: 0FE     Fe  363   1.784   2.636   0.284
# - Atom line 366 is too short: 0FE     Fe  364   1.926   2.494   0.142
# - Atom line 367 is too short: 0FE     Fe  365   1.784   2.636   0.568
# - Atom line 368 is too short: 0FE     Fe  366   1.926   2.494   0.426
# - Atom line 369 is too short: 0FE     Fe  367   1.784   2.920   0.000
# - Atom line 370 is too short: 0FE     Fe  368   1.784   2.920   0.284
# - Atom line 371 is too short: 0FE     Fe  369   1.926   2.778   0.142
# - Atom line 372 is too short: 0FE     Fe  370   1.784   2.920   0.568
# - Atom line 373 is too short: 0FE     Fe  371   1.926   2.778   0.426
# - Atom line 374 is too short: 0FE     Fe  372   2.068   0.080   0.000
# - Atom line 375 is too short: 0FE     Fe  373   2.068   0.080   0.284
# - Atom line 376 is too short: 0FE     Fe  374   2.068   0.080   0.568
# - Atom line 377 is too short: 0FE     Fe  375   2.068   0.364   0.000
# - Atom line 378 is too short: 0FE     Fe  376   2.068   0.364   0.284
# - Atom line 379 is too short: 0FE     Fe  377   2.210   0.222   0.142
# - Atom line 380 is too short: 0FE     Fe  378   2.068   0.364   0.568
# - Atom line 381 is too short: 0FE     Fe  379   2.210   0.222   0.426
# - Atom line 382 is too short: 0FE     Fe  380   2.068   0.648   0.000
# - Atom line 383 is too short: 0FE     Fe  381   2.068   0.648   0.284
# - Atom line 384 is too short: 0FE     Fe  382   2.210   0.506   0.142
# - Atom line 385 is too short: 0FE     Fe  383   2.068   0.648   0.568
# - Atom line 386 is too short: 0FE     Fe  384   2.210   0.506   0.426
# - Atom line 387 is too short: 0FE     Fe  385   2.068   0.932   0.000
# - Atom line 388 is too short: 0FE     Fe  386   2.068   0.932   0.284
# - Atom line 389 is too short: 0FE     Fe  387   2.210   0.790   0.142
# - Atom line 390 is too short: 0FE     Fe  388   2.068   0.932   0.568
# - Atom line 391 is too short: 0FE     Fe  389   2.210   0.790   0.426
# - Atom line 392 is too short: 0FE     Fe  390   2.068   1.216   0.000
# - Atom line 393 is too short: 0FE     Fe  391   2.068   1.216   0.284
# - Atom line 394 is too short: 0FE     Fe  392   2.210   1.074   0.142
# - Atom line 395 is too short: 0FE     Fe  393   2.068   1.216   0.568
# - Atom line 396 is too short: 0FE     Fe  394   2.210   1.074   0.426
# - Atom line 397 is too short: 0FE     Fe  395   2.068   1.500   0.000
# - Atom line 398 is too short: 0FE     Fe  396   2.068   1.500   0.284
# - Atom line 399 is too short: 0FE     Fe  397   2.210   1.358   0.142
# - Atom line 400 is too short: 0FE     Fe  398   2.068   1.500   0.568
# - Atom line 401 is too short: 0FE     Fe  399   2.210   1.358   0.426
# - Atom line 402 is too short: 0FE     Fe  400   2.068   1.784   0.000
# - Atom line 403 is too short: 0FE     Fe  401   2.068   1.784   0.284
# - Atom line 404 is too short: 0FE     Fe  402   2.210   1.642   0.142
# - Atom line 405 is too short: 0FE     Fe  403   2.068   1.784   0.568
# - Atom line 406 is too short: 0FE     Fe  404   2.210   1.642   0.426
# - Atom line 407 is too short: 0FE     Fe  405   2.068   2.068   0.000
# - Atom line 408 is too short: 0FE     Fe  406   2.068   2.068   0.284
# - Atom line 409 is too short: 0FE     Fe  407   2.210   1.926   0.142
# - Atom line 410 is too short: 0FE     Fe  408   2.068   2.068   0.568
# - Atom line 411 is too short: 0FE     Fe  409   2.210   1.926   0.426
# - Atom line 412 is too short: 0FE     Fe  410   2.068   2.352   0.000
# - Atom line 413 is too short: 0FE     Fe  411   2.068   2.352   0.284
# - Atom line 414 is too short: 0FE     Fe  412   2.210   2.210   0.142
# - Atom line 415 is too short: 0FE     Fe  413   2.068   2.352   0.568
# - Atom line 416 is too short: 0FE     Fe  414   2.210   2.210   0.426
# - Atom line 417 is too short: 0FE     Fe  415   2.068   2.636   0.000
# - Atom line 418 is too short: 0FE     Fe  416   2.068   2.636   0.284
# - Atom line 419 is too short: 0FE     Fe  417   2.210   2.494   0.142
# - Atom line 420 is too short: 0FE     Fe  418   2.068   2.636   0.568
# - Atom line 421 is too short: 0FE     Fe  419   2.210   2.494   0.426
# - Atom line 422 is too short: 0FE     Fe  420   2.068   2.920   0.000
# - Atom line 423 is too short: 0FE     Fe  421   2.068   2.920   0.284
# - Atom line 424 is too short: 0FE     Fe  422   2.210   2.778   0.142
# - Atom line 425 is too short: 0FE     Fe  423   2.068   2.920   0.568
# - Atom line 426 is too short: 0FE     Fe  424   2.210   2.778   0.426
# - Atom line 427 is too short: 0FE     Fe  425   2.352   0.080   0.000
# - Atom line 428 is too short: 0FE     Fe  426   2.352   0.080   0.284
# - Atom line 429 is too short: 0FE     Fe  427   2.352   0.080   0.568
# - Atom line 430 is too short: 0FE     Fe  428   2.352   0.364   0.000
# - Atom line 431 is too short: 0FE     Fe  429   2.352   0.364   0.284
# - Atom line 432 is too short: 0FE     Fe  430   2.494   0.222   0.142
# - Atom line 433 is too short: 0FE     Fe  431   2.352   0.364   0.568
# - Atom line 434 is too short: 0FE     Fe  432   2.494   0.222   0.426
# - Atom line 435 is too short: 0FE     Fe  433   2.352   0.648   0.000
# - Atom line 436 is too short: 0FE     Fe  434   2.352   0.648   0.284
# - Atom line 437 is too short: 0FE     Fe  435   2.494   0.506   0.142
# - Atom line 438 is too short: 0FE     Fe  436   2.352   0.648   0.568
# - Atom line 439 is too short: 0FE     Fe  437   2.494   0.506   0.426
# - Atom line 440 is too short: 0FE     Fe  438   2.352   0.932   0.000
# - Atom line 441 is too short: 0FE     Fe  439   2.352   0.932   0.284
# - Atom line 442 is too short: 0FE     Fe  440   2.494   0.790   0.142
# - Atom line 443 is too short: 0FE     Fe  441   2.352   0.932   0.568
# - Atom line 444 is too short: 0FE     Fe  442   2.494   0.790   0.426
# - Atom line 445 is too short: 0FE     Fe  443   2.352   1.216   0.000
# - Atom line 446 is too short: 0FE     Fe  444   2.352   1.216   0.284
# - Atom line 447 is too short: 0FE     Fe  445   2.494   1.074   0.142
# - Atom line 448 is too short: 0FE     Fe  446   2.352   1.216   0.568
# - Atom line 449 is too short: 0FE     Fe  447   2.494   1.074   0.426
# - Atom line 450 is too short: 0FE     Fe  448   2.352   1.500   0.000
# - Atom line 451 is too short: 0FE     Fe  449   2.352   1.500   0.284
# - Atom line 452 is too short: 0FE     Fe  450   2.494   1.358   0.142
# - Atom line 453 is too short: 0FE     Fe  451   2.352   1.500   0.568
# - Atom line 454 is too short: 0FE     Fe  452   2.494   1.358   0.426
# - Atom line 455 is too short: 0FE     Fe  453   2.352   1.784   0.000
# - Atom line 456 is too short: 0FE     Fe  454   2.352   1.784   0.284
# - Atom line 457 is too short: 0FE     Fe  455   2.494   1.642   0.142
# - Atom line 458 is too short: 0FE     Fe  456   2.352   1.784   0.568
# - Atom line 459 is too short: 0FE     Fe  457   2.494   1.642   0.426
# - Atom line 460 is too short: 0FE     Fe  458   2.352   2.068   0.000
# - Atom line 461 is too short: 0FE     Fe  459   2.352   2.068   0.284
# - Atom line 462 is too short: 0FE     Fe  460   2.494   1.926   0.142
# - Atom line 463 is too short: 0FE     Fe  461   2.352   2.068   0.568
# - Atom line 464 is too short: 0FE     Fe  462   2.494   1.926   0.426
# - Atom line 465 is too short: 0FE     Fe  463   2.352   2.352   0.000
# - Atom line 466 is too short: 0FE     Fe  464   2.352   2.352   0.284
# - Atom line 467 is too short: 0FE     Fe  465   2.494   2.210   0.142
# - Atom line 468 is too short: 0FE     Fe  466   2.352   2.352   0.568
# - Atom line 469 is too short: 0FE     Fe  467   2.494   2.210   0.426
# - Atom line 470 is too short: 0FE     Fe  468   2.352   2.636   0.000
# - Atom line 471 is too short: 0FE     Fe  469   2.352   2.636   0.284
# - Atom line 472 is too short: 0FE     Fe  470   2.494   2.494   0.142
# - Atom line 473 is too short: 0FE     Fe  471   2.352   2.636   0.568
# - Atom line 474 is too short: 0FE     Fe  472   2.494   2.494   0.426
# - Atom line 475 is too short: 0FE     Fe  473   2.352   2.920   0.000
# - Atom line 476 is too short: 0FE     Fe  474   2.352   2.920   0.284
# - Atom line 477 is too short: 0FE     Fe  475   2.494   2.778   0.142
# - Atom line 478 is too short: 0FE     Fe  476   2.352   2.920   0.568
# - Atom line 479 is too short: 0FE     Fe  477   2.494   2.778   0.426
# - Atom line 480 is too short: 0FE     Fe  478   2.636   0.080   0.000
# - Atom line 481 is too short: 0FE     Fe  479   2.636   0.080   0.284
# - Atom line 482 is too short: 0FE     Fe  480   2.636   0.080   0.568
# - Atom line 483 is too short: 0FE     Fe  481   2.636   0.364   0.000
# - Atom line 484 is too short: 0FE     Fe  482   2.636   0.364   0.284
# - Atom line 485 is too short: 0FE     Fe  483   2.778   0.222   0.142
# - Atom line 486 is too short: 0FE     Fe  484   2.636   0.364   0.568
# - Atom line 487 is too short: 0FE     Fe  485   2.778   0.222   0.426
# - Atom line 488 is too short: 0FE     Fe  486   2.636   0.648   0.000
# - Atom line 489 is too short: 0FE     Fe  487   2.636   0.648   0.284
# - Atom line 490 is too short: 0FE     Fe  488   2.778   0.506   0.142
# - Atom line 491 is too short: 0FE     Fe  489   2.636   0.648   0.568
# - Atom line 492 is too short: 0FE     Fe  490   2.778   0.506   0.426
# - Atom line 493 is too short: 0FE     Fe  491   2.636   0.932   0.000
# - Atom line 494 is too short: 0FE     Fe  492   2.636   0.932   0.284
# - Atom line 495 is too short: 0FE     Fe  493   2.778   0.790   0.142
# - Atom line 496 is too short: 0FE     Fe  494   2.636   0.932   0.568
# - Atom line 497 is too short: 0FE     Fe  495   2.778   0.790   0.426
# - Atom line 498 is too short: 0FE     Fe  496   2.636   1.216   0.000
# - Atom line 499 is too short: 0FE     Fe  497   2.636   1.216   0.284
# - Atom line 500 is too short: 0FE     Fe  498   2.778   1.074   0.142
# - Atom line 501 is too short: 0FE     Fe  499   2.636   1.216   0.568
# - Atom line 502 is too short: 0FE     Fe  500   2.778   1.074   0.426
# - Atom line 503 is too short: 0FE     Fe  501   2.636   1.500   0.000
# - Atom line 504 is too short: 0FE     Fe  502   2.636   1.500   0.284
# - Atom line 505 is too short: 0FE     Fe  503   2.778   1.358   0.142
# - Atom line 506 is too short: 0FE     Fe  504   2.636   1.500   0.568
# - Atom line 507 is too short: 0FE     Fe  505   2.778   1.358   0.426
# - Atom line 508 is too short: 0FE     Fe  506   2.636   1.784   0.000
# - Atom line 509 is too short: 0FE     Fe  507   2.636   1.784   0.284
# - Atom line 510 is too short: 0FE     Fe  508   2.778   1.642   0.142
# - Atom line 511 is too short: 0FE     Fe  509   2.636   1.784   0.568
# - Atom line 512 is too short: 0FE     Fe  510   2.778   1.642   0.426
# - Atom line 513 is too short: 0FE     Fe  511   2.636   2.068   0.000
# - Atom line 514 is too short: 0FE     Fe  512   2.636   2.068   0.284
# - Atom line 515 is too short: 0FE     Fe  513   2.778   1.926   0.142
# - Atom line 516 is too short: 0FE     Fe  514   2.636   2.068   0.568
# - Atom line 517 is too short: 0FE     Fe  515   2.778   1.926   0.426
# - Atom line 518 is too short: 0FE     Fe  516   2.636   2.352   0.000
# - Atom line 519 is too short: 0FE     Fe  517   2.636   2.352   0.284
# - Atom line 520 is too short: 0FE     Fe  518   2.778   2.210   0.142
# - Atom line 521 is too short: 0FE     Fe  519   2.636   2.352   0.568
# - Atom line 522 is too short: 0FE     Fe  520   2.778   2.210   0.426
# - Atom line 523 is too short: 0FE     Fe  521   2.636   2.636   0.000
# - Atom line 524 is too short: 0FE     Fe  522   2.636   2.636   0.284
# - Atom line 525 is too short: 0FE     Fe  523   2.778   2.494   0.142
# - Atom line 526 is too short: 0FE     Fe  524   2.636   2.636   0.568
# - Atom line 527 is too short: 0FE     Fe  525   2.778   2.494   0.426
# - Atom line 528 is too short: 0FE     Fe  526   2.636   2.920   0.000
# - Atom line 529 is too short: 0FE     Fe  527   2.636   2.920   0.284
# - Atom line 530 is too short: 0FE     Fe  528   2.778   2.778   0.142
# - Atom line 531 is too short: 0FE     Fe  529   2.636   2.920   0.568
# - Atom line 532 is too short: 0FE     Fe  530   2.778   2.778   0.426
# - Atom line 533 is too short: 0FE     Fe  531   2.920   0.080   0.000
# - Atom line 534 is too short: 0FE     Fe  532   2.920   0.080   0.284
# - Atom line 535 is too short: 0FE     Fe  533   2.920   0.080   0.568
# - Atom line 536 is too short: 0FE     Fe  534   2.920   0.364   0.000
# - Atom line 537 is too short: 0FE     Fe  535   2.920   0.364   0.284
# - Atom line 538 is too short: 0FE     Fe  536   2.920   0.364   0.568
# - Atom line 539 is too short: 0FE     Fe  537   2.920   0.648   0.000
# - Atom line 540 is too short: 0FE     Fe  538   2.920   0.648   0.284
# - Atom line 541 is too short: 0FE     Fe  539   2.920   0.648   0.568
# - Atom line 542 is too short: 0FE     Fe  540   2.920   0.932   0.000
# - Atom line 543 is too short: 0FE     Fe  541   2.920   0.932   0.284
# - Atom line 544 is too short: 0FE     Fe  542   2.920   0.932   0.568
# - Atom line 545 is too short: 0FE     Fe  543   2.920   1.216   0.000
# - Atom line 546 is too short: 0FE     Fe  544   2.920   1.216   0.284
# - Atom line 547 is too short: 0FE     Fe  545   2.920   1.216   0.568
# - Atom line 548 is too short: 0FE     Fe  546   2.920   1.500   0.000
# - Atom line 549 is too short: 0FE     Fe  547   2.920   1.500   0.284
# - Atom line 550 is too short: 0FE     Fe  548   2.920   1.500   0.568
# - Atom line 551 is too short: 0FE     Fe  549   2.920   1.784   0.000
# - Atom line 552 is too short: 0FE     Fe  550   2.920   1.784   0.284
# - Atom line 553 is too short: 0FE     Fe  551   2.920   1.784   0.568
# - Atom line 554 is too short: 0FE     Fe  552   2.920   2.068   0.000
# - Atom line 555 is too short: 0FE     Fe  553   2.920   2.068   0.284
# - Atom line 556 is too short: 0FE     Fe  554   2.920   2.068   0.568
# - Atom line 557 is too short: 0FE     Fe  555   2.920   2.352   0.000
# - Atom line 558 is too short: 0FE     Fe  556   2.920   2.352   0.284
# - Atom line 559 is too short: 0FE     Fe  557   2.920   2.352   0.568
# - Atom line 560 is too short: 0FE     Fe  558   2.920   2.636   0.000
# - Atom line 561 is too short: 0FE     Fe  559   2.920   2.636   0.284
# - Atom line 562 is too short: 0FE     Fe  560   2.920   2.636   0.568
# - Atom line 563 is too short: 0FE     Fe  561   2.920   2.920   0.000
# - Atom line 564 is too short: 0FE     Fe  562   2.920   2.920   0.284
# - Atom line 565 is too short: 0FE     Fe  563   2.920   2.920   0.568
# The GRO file is invalid. Please fix the reported issues.

# %% [markdown]
# ### CHECK THE SLAB COORDINATIONS

# %% [markdown]
# ## SLAB ADJUSTMENT [info]

# %%
import numpy as np

def read_gro_file(filename):
    """
    Reads atomic positions and box dimensions from a .gro file.
    Returns:
        - z_coords: List of z-coordinates of all atoms.
        - box_height: Height of the simulation box (in nm).
    """
    z_coords = []
    box_height = 0.0
    try:
        with open(filename, 'r') as file:
            lines = file.readlines()
            
            # Number of atoms is indicated on the second line
            atom_count = int(lines[1].strip())
            
            # Extract atom data (lines 3 to atom_count + 2)
            for line in lines[2:2 + atom_count]:
                parts = line.split()
                z_coords.append(float(parts[-1]))  # z-coordinate is the last column
            
            # Extract box dimensions from the last line
            box_line = lines[-1]
            box_height = float(box_line.split()[-1])  # z-dimension is the last value
    except FileNotFoundError:
        print(f"Error: File '{filename}' not found.")
    except ValueError as ve:
        print(f"Error while reading the file: {ve}")
    
    # Check if z-coordinates were extracted
    if len(z_coords) == 0:
        print("Warning: No valid z-coordinates were found in the file.")
    
    return np.array(z_coords), box_height

def calculate_slab_properties(z_coords, box_height):
    """
    Calculates slab thickness, space above and below the slab, and total box height.
    Args:
        - z_coords: List/array of z-coordinates of all atoms.
        - box_height: Total height of the simulation box.
    Returns:
        - slab_thickness: Thickness of the slab (in nm).
        - space_above: Space above the slab (in nm).
        - space_below: Space below the slab (in nm).
        - adjustment_height: Height needed to move slab to the bottom of the box.
        - box_height: Total box height (in nm).
    """
    if len(z_coords) == 0:
        raise ValueError("z_coords array is empty. Ensure valid data is provided.")
    
    z_min = np.min(z_coords)  # Lowest z-coordinate (bottom of the slab)
    z_max = np.max(z_coords)  # Highest z-coordinate (top of the slab)
    slab_thickness = z_max - z_min
    space_below = z_min
    space_above = box_height - z_max
    adjustment_height = -z_min  # Negative z_min to move the slab down to z = 0
    return slab_thickness, space_above, space_below, adjustment_height, box_height

def main():
    # Input file name
    gro_filename = "/mnt/new_volume/newsitt/topic1/dtac/conf.gro"
    
    # Read atomic positions and box height
    z_coords, box_height = read_gro_file(gro_filename)
    
    try:
        # Calculate slab properties
        slab_thickness, space_above, space_below, adjustment_height, total_height = calculate_slab_properties(z_coords, box_height)
        
        # Print results
        print(f"Slab Thickness: {slab_thickness:.3f} nm")
        print(f"Space Below the Slab: {space_below:.3f} nm")
        print(f"Space Above the Slab: {space_above:.3f} nm")
        print(f"Total Height of the Simulation Box: {total_height:.3f} nm")
        print(f"Height Adjustment to Move Slab to Bottom: {adjustment_height:.3f} nm")
    except ValueError as ve:
        print(f"Error in calculation: {ve}")

if __name__ == "__main__":
    main()
# Out:
# Slab Thickness: 3.857 nm
# Space Below the Slab: -0.053 nm
# Space Above the Slab: -0.129 nm
# Total Height of the Simulation Box: 3.675 nm
# Height Adjustment to Move Slab to Bottom: 0.053 nm

# %%
import numpy as np
from collections import Counter

def read_gro_file(filename):
    """
    Reads atomic positions, residues, atom names, and box dimensions from a .gro file.
    Returns:
        - z_coords: List of z-coordinates of all atoms.
        - residue_counts: Dictionary with residue names as keys and their atom counts as values.
        - total_atoms: Total number of atoms in the file.
        - box_height: Height of the simulation box (in nm).
    """
    z_coords = []
    residues = []
    box_height = 0.0
    total_atoms = 0
    try:
        with open(filename, 'r') as file:
            lines = file.readlines()
            
            # Number of atoms is indicated on the second line
            total_atoms = int(lines[1].strip())
            
            # Extract atom data (lines 3 to total_atoms + 2)
            for line in lines[2:2 + total_atoms]:
                parts = line.split()
                
                # Ensure the line has enough parts to extract data
                if len(parts) >= 5:
                    residue_name = parts[0]  # Residue name
                    residues.append(residue_name)
                    z_coords.append(float(parts[-1]))  # z-coordinate is the last column
            
            # Extract box dimensions from the last line
            box_line = lines[-1]
            box_height = float(box_line.split()[-1])  # z-dimension is the last value
    except FileNotFoundError:
        print(f"Error: File '{filename}' not found.")
    except ValueError as ve:
        print(f"Error while reading the file: {ve}")
    
    # Count the number of atoms for each residue
    residue_counts = Counter(residues)
    
    # Check if z-coordinates were extracted
    if len(z_coords) == 0:
        print("Warning: No valid z-coordinates were found in the file.")
    
    return np.array(z_coords), residue_counts, total_atoms, box_height

def calculate_slab_properties(z_coords, box_height):
    """
    Calculates slab thickness, space above and below the slab, and total box height.
    Args:
        - z_coords: List/array of z-coordinates of all atoms.
        - box_height: Total height of the simulation box.
    Returns:
        - slab_thickness: Thickness of the slab (in nm).
        - space_above: Space above the slab (in nm).
        - space_below: Space below the slab (in nm).
        - adjustment_height: Height needed to move slab to the bottom of the box.
        - box_height: Total box height (in nm).
    """
    if len(z_coords) == 0:
        raise ValueError("z_coords array is empty. Ensure valid data is provided.")
    
    z_min = np.min(z_coords)  # Lowest z-coordinate (bottom of the slab)
    z_max = np.max(z_coords)  # Highest z-coordinate (top of the slab)
    slab_thickness = z_max - z_min
    space_below = z_min
    space_above = box_height - z_max
    adjustment_height = -z_min  # Negative z_min to move the slab down to z = 0
    return slab_thickness, space_above, space_below, adjustment_height, box_height

def main():
    # Input file name
    gro_filename = "/mnt/new_volume/newsitt/topic1/bdac/prep_conf.gro"
    
    # Read atomic positions, residue counts, total atoms, and box height
    z_coords, residue_counts, total_atoms, box_height = read_gro_file(gro_filename)
    
    try:
        # Calculate slab properties
        slab_thickness, space_above, space_below, adjustment_height, total_height = calculate_slab_properties(z_coords, box_height)
        
        # Print results
        print(f"Total Atoms in the GRO File: {total_atoms}")
        print(f"Slab Thickness: {slab_thickness:.3f} nm")
        print(f"Space Below the Slab: {space_below:.3f} nm")
        print(f"Space Above the Slab: {space_above:.3f} nm")
        print(f"Total Height of the Simulation Box: {total_height:.3f} nm")
        print(f"Height Adjustment to Move Slab to Bottom: {adjustment_height:.3f} nm")
        
        # Print residue counts
        if residue_counts:
            print("\nNumber of Atoms for Each Residue:")
            print(f"{'Residue':<10} {'Atom Count':<10}")
            print("-" * 20)
            for residue, count in residue_counts.items():
                print(f"{residue:<10} {count:<10}")
        else:
            print("No residues found in the GRO file.")
    except ValueError as ve:
        print(f"Error in calculation: {ve}")

if __name__ == "__main__":
    main()
# Out:
# Total Atoms in the GRO File: 2442
# Slab Thickness: 2.950 nm
# Space Below the Slab: 0.060 nm
# Space Above the Slab: 1.990 nm
# Total Height of the Simulation Box: 5.000 nm
# Height Adjustment to Move Slab to Bottom: -0.060 nm
#
# Number of Atoms for Each Residue:
# Residue    Atom Count
# --------------------
# 1Fe        1
# 2Fe        1
# 3Fe        1
# 4Fe        1
# 5Fe        1
# 6Fe        1
# 7Fe        1
# 8Fe        1
# 9Fe        1
# 10Fe       1
# 11Fe       1
# 12Fe       1
# 13Fe       1
# 14Fe       1
# 15Fe       1
# 16Fe       1
# 17Fe       1
# 18Fe       1
# 19Fe       1
# 20Fe       1
# 21Fe       1
# 22Fe       1
# 23Fe       1
# 24Fe       1
# 25Fe       1
# 26Fe       1
# 27Fe       1
# 28Fe       1
# 29Fe       1
# 30Fe       1
# 31Fe       1
# 32Fe       1
# 33Fe       1
# 34Fe       1
# 35Fe       1
# 36Fe       1
# 37Fe       1
# 38Fe       1
# 39Fe       1
# 40Fe       1
# 41Fe       1
# 42Fe       1
# 43Fe       1
# 44Fe       1
# 45Fe       1
# 46Fe       1
# 47Fe       1
# 48Fe       1
# 49Fe       1
# 50Fe       1
# 51Fe       1
# 52Fe       1
# 53Fe       1
# 54Fe       1
# 55Fe       1
# 56Fe       1
# 57Fe       1
# 58Fe       1
# 59Fe       1
# 60Fe       1
# 61Fe       1
# 62Fe       1
# 63Fe       1
# 64Fe       1
# 65Fe       1
# 66Fe       1
# 67Fe       1
# 68Fe       1
# 69Fe       1
# 70Fe       1
# 71Fe       1
# 72Fe       1
# 73Fe       1
# 74Fe       1
# 75Fe       1
# 76Fe       1
# 77Fe       1
# 78Fe       1
# 79Fe       1
# 80Fe       1
# 81Fe       1
# 82Fe       1
# 83Fe       1
# 84Fe       1
# 85Fe       1
# 86Fe       1
# 87Fe       1
# 88Fe       1
# 89Fe       1
# 90Fe       1
# 91Fe       1
# 92Fe       1
# 93Fe       1
# 94Fe       1
# 95Fe       1
# 96Fe       1
# 97Fe       1
# 1114SOL    3
# 1115SOL    3
# 1116SOL    3
# 1117SOL    3
# 1118SOL    3
# 1119SOL    3
# 1120SOL    3
# 1121SOL    3
# 1122SOL    3
# 1123SOL    3
# 1124SOL    3
# 1125SOL    3
# 1126SOL    3
# 1127SOL    3
# 1128SOL    3
# 1129SOL    3
# 1130SOL    3
# 1131SOL    3
# 1132SOL    3
# 1133SOL    3
# 1134SOL    3
# 1135SOL    3
# 1136SOL    3
# 1137SOL    3
# 1138SOL    3
# 1139SOL    3
# 1140SOL    3
# 1141SOL    3
# 1142SOL    3
# 1143SOL    3
# 1144SOL    3
# 1145SOL    3
# 1146SOL    3
# 1147SOL    3
# 1148SOL    3
# 1149SOL    3
# 1150SOL    3
# 1151SOL    3
# 1152SOL    3
# 1153SOL    3
# 1154SOL    3
# 1155SOL    3
# 1156SOL    3
# 1157SOL    3
# 1158SOL    3
# 1159SOL    3
# 1160SOL    3
# 1161SOL    3
# 1162SOL    3
# 1163SOL    3
# 1164SOL    3
# 1165SOL    3
# 1166SOL    3
# 1167SOL    3
# 1168SOL    3
# 1169SOL    3
# 1170SOL    3
# 1171CL     1

# %% [markdown]
# # FILE PREPARATION

# %%
import MDAnalysis as mda
from MDAnalysis.coordinates import GRO

def xyz_to_gro(xyz_file, gro_file):
    u = mda.Universe(xyz_file, format="XYZ")
    with mda.Writer(gro_file, n_atoms=u.atoms.n_atoms) as W:
        W.write(u.atoms)
    print(f"Conversion complete: {gro_file}")

xyz_to_gro("slab.xyz", "slab.gro")
# Out:
# Conversion complete: slab.gro
# /home/usac/Desktop/newsitt/thesis/venv/lib/python3.12/site-packages/MDAnalysis/coordinates/GRO.py:421: UserWarning: Supplied AtomGroup was missing the following attributes: resnames. These will be written with default values. Alternatively these can be supplied as keyword arguments.
#   warnings.warn(
# /home/usac/Desktop/newsitt/thesis/venv/lib/python3.12/site-packages/MDAnalysis/coordinates/GRO.py:479: UserWarning: missing dimension - setting unit cell to zeroed box [0., 0., 0.]
#   warnings.warn(wmsg)

# %% [markdown]
# ## COORDINATE SCREENING

# %%
import py3Dmol

# Load the .gro file
with open("/mnt/new_volume/newsitt/topic1/dtac/box.gro") as gro_file:
    gro_data = gro_file.read()

# Create a py3Dmol viewer
viewer = py3Dmol.view()
viewer.addModel(gro_data, "gro")  # Add .gro file data
viewer.setStyle({"sphere": {}})  # Show atoms as spheres
viewer.zoomTo()

# Display the viewer
viewer.show()
# Out:
# <div id="3dmolviewer_17380448836195886"  style="position: relative; width: 640px; height: 480px;">
#         <p id="3dmolwarning_17380448836195886" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.4.2/3Dmol-min.js');
# }
#
# var viewer_17380448836195886 = null;
# var warn = document.getElementById("3dmolwarning_17380448836195886");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17380448836195886 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17380448836195886"),{backgroundColor:"white"});
# viewer_17380448836195886.zoomTo();
   1.627\n    0FE      Fe   71   0.506   0.815   1.485\n    0FE      Fe   72   0.364   1.241   1.059\n    0FE      Fe   73   0.364   1.241   1.343\n    0FE      Fe   74   0.506   1.099   1.201\n    0FE      Fe   75   0.364   1.241   1.627\n    0FE      Fe   76   0.506   1.099   1.485\n    0FE      Fe   77   0.364   1.525   1.059\n    0FE      Fe   78   0.364   1.525   1.343\n    0FE      Fe   79   0.506   1.383   1.201\n    0FE      Fe   80   0.364   1.525   1.627\n    0FE      Fe   81   0.506   1.383   1.485\n    0FE      Fe   82   0.364   1.809   1.059\n    0FE      Fe   83   0.364   1.809   1.343\n    0FE      Fe   84   0.506   1.667   1.201\n    0FE      Fe   85   0.364   1.809   1.627\n    ...

# %%
import py3Dmol

def read_gro_file_with_box_and_units(filename):
    """
    Reads atomic positions and box dimensions from a .gro file.
    Converts units from nanometers to angstroms for py3Dmol visualization.
    Returns:
        - gro_data: The entire contents of the .gro file as a string.
        - box_dims: Dimensions of the simulation box in angstroms as (x, y, z).
    """
    box_dims = (0.0, 0.0, 0.0)
    try:
        with open(filename, "r") as file:
            gro_data = file.read()
            
            # Extract the last line for box dimensions
            lines = gro_data.strip().split("\n")
            box_line = lines[-1].split()
            if len(box_line) >= 3:
                # Convert box dimensions from nm to Å
                box_dims = tuple(float(dim) * 10 for dim in box_line[:3])
                print(f"Extracted box dimensions (in Å): {box_dims}")
            else:
                print("Box dimensions line is invalid.")
    except FileNotFoundError:
        print(f"Error: File '{filename}' not found.")
    except ValueError as ve:
        print(f"Error while reading the file: {ve}")
    
    return gro_data, box_dims

def visualize_gro_with_box_units(gro_data, box_dims):
    """
    Visualizes the .gro file with simulation box edges using py3Dmol.
    Converts the box dimensions and coordinates to angstroms.
    Args:
        - gro_data: The .gro file contents as a string.
        - box_dims: Dimensions of the simulation box in angstroms as (x, y, z).
    """
    if box_dims == (0.0, 0.0, 0.0):
        print("Invalid box dimensions. Cannot draw simulation box.")
        return

    viewer = py3Dmol.view(width=800, height=600)
    
    # Add the molecular structure from the .gro file
    viewer.addModel(gro_data, "gro")  # Load .gro file
    viewer.setStyle({"sphere": {"scale": 0.3}})  # Atoms as spheres
    
    # Add the box edges (in Å)
    x_len, y_len, z_len = box_dims
    box_lines = [
        [[0, 0, 0], [x_len, 0, 0]], [[x_len, 0, 0], [x_len, y_len, 0]],
        [[x_len, y_len, 0], [0, y_len, 0]], [[0, y_len, 0], [0, 0, 0]],  # Bottom face
        [[0, 0, z_len], [x_len, 0, z_len]], [[x_len, 0, z_len], [x_len, y_len, z_len]],
        [[x_len, y_len, z_len], [0, y_len, z_len]], [[0, y_len, z_len], [0, 0, z_len]],  # Top face
        [[0, 0, 0], [0, 0, z_len]], [[x_len, 0, 0], [x_len, 0, z_len]],
        [[x_len, y_len, 0], [x_len, y_len, z_len]], [[0, y_len, 0], [0, y_len, z_len]]  # Vertical edges
    ]
    for line in box_lines:
        viewer.addCylinder({"start": {"x": line[0][0], "y": line[0][1], "z": line[0][2]},
                            "end": {"x": line[1][0], "y": line[1][1], "z": line[1][2]},
                            "radius": 0.1, "color": "gray"})

    # Center and zoom the viewer
    viewer.zoomTo()
    
    # Show the viewer
    return viewer.show()

def main():
    # Input .gro file
    gro_filename = "/mnt/new_volume/newsitt/topic1/slab/solvated.gro"
    
    # Read the .gro file and box dimensions
    gro_data, box_dims = read_gro_file_with_box_and_units(gro_filename)
    
    # Visualize the .gro file with the simulation box
    visualize_gro_with_box_units(gro_data, box_dims)

if __name__ == "__main__":
    main()
# Out:
# Extracted box dimensions (in Å): (30.0, 30.0, 30.0)
# <div id="3dmolviewer_17380442973488503"  style="position: relative; width: 800px; height: 600px;">
#         <p id="3dmolwarning_17380442973488503" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.4.2/3Dmol-min.js');
# }
#
# var viewer_17380442973488503 = null;
# var warn = document.getElementById("3dmolwarning_17380442973488503");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17380442973488503 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17380442973488503"),{backgroundColor:"white"});
# viewer_17380442973488503.zoomTo();
# 	viewer_17380442973488503.addModel("ADSORPTION STUDIES OF CATIONIC SURFACTANTS\n 2444\n    0FE      Fe    1   0.080   0.080   0.000\n    0FE      Fe    2   0.080   0.080   0.284\n    0FE      Fe    3   0.080   0.080   0.568\n    0FE      Fe    4   0.080   0.364   0.000\n    0FE      Fe    5   0.080   0.364   0.284\n    0FE      Fe    6   0.222   0.222   0.142\n    0FE      Fe    7   0.080   0.364   0.568\n    0FE      Fe    8   0.222   0.222   0.426\n    0FE      Fe    9   0.080   0.648   0.000\n    0FE      Fe   10   0.080   0.648   0.284\n    0FE      Fe   11   0.222   0.506   0.142\n    0FE      Fe   12   0.080   0.648   0.568\n    0FE      Fe   13   0.222   0.506   0.426\n    0FE      Fe   14   0.080   0.932   0.000\n    0FE      Fe   15   0.080   0.932   0.284\n    0FE      Fe   16   0.222   0.790   0.142\n    0FE      Fe   17   0.080   0.932   0.568\n    0FE      Fe   18   0.222   0.790   0.426\n    0FE      Fe   19   0.080   1.216   0.000\n    0FE      Fe   20   0.080   1.216   0.284\n    0FE      Fe   21   0.222   1.074   0.142\n    0FE      Fe   22   0.080   1.216   0.568\n    0FE      Fe   23   0.222   1.074   0.426\n    0FE      Fe   24   0.080   1.500   0.000\n    0FE      Fe   25   0.080   1.500   0.284\n    0FE      Fe   26   0.222   1.358   0.142\n    0FE      Fe   27   0.080   1.500   0.568\n    0FE      Fe   28   0.222   1.358   0.426\n    0FE      Fe   29   0.080   1.784   0.000\n    0FE      Fe   30   0.080   1.784   0.284\n    0FE      Fe   31   0.222   1.642   0.142\n    0FE      Fe   32   0.080   1.784   0.568\n    0FE      Fe   33   0.222   1.642   0.426\n    0FE      Fe   34   0.080   2.068   0.000\n    0FE      Fe   35   0.080   2.068   0.284\n    0FE      Fe   36   0.222   1.926   0.142\n    0FE      Fe   37   0.080   2.068   0.568\n    0FE      Fe   38   0.222   1.926   0.426\n    0FE      Fe   39   0.080   2.352   0.000\n    0FE      Fe   40   0.080   2.352   0.284\n    0FE      Fe   41   0.222   2.210   0.142\n    0FE      Fe   42   0.080   2.352   0.568\n    0FE      Fe   43   0.222   2.210   0.426\n    0FE      Fe   44   0.080   2.636   0.000\n    0FE      Fe   45   0.080   2.636   0.284\n    0FE      Fe   46   0.222   2.494   0.142\n    0FE      Fe   47   0.080   2.636   0.568\n    0FE      Fe   48   0.222   2.494   0.426\n    0FE      Fe   49   0.080   2.920   0.000\n    0FE      Fe   50   0.080   2.920   0.284\n    0FE      Fe   51   0.222   2.778   0.142\n    0FE      Fe   52   0.080   2.920   0.568\n    0FE      Fe   53   0.222   2.778   0.426\n    0FE      Fe   54   0.364   0.080   0.000\n    0FE      Fe   55   0.364   0.080   0.284\n    0FE      Fe   56   0.364   0.080   0.568\n    0FE      Fe   57   0.364   0.364   0.000\n    0FE      Fe   58   0.364   0.364   0.284\n    0FE      Fe   59   0.506   0.222   0.142\n    0FE      Fe   60   0.364   0.364   0.568\n    0FE      Fe   61   0.506   0.222   0.426\n    0FE      Fe   62   0.364   0.648   0.000\n    0FE      Fe   63   0.364   0.648   0.284\n    0FE      Fe   64   0.506   0.506   0.142\n    0FE      Fe   65   0.364   0.648   0.568\n    0FE      Fe   66   0.506   0.506   0.426\n    0FE      Fe   67   0.364   0.932   0.000\n    0FE      Fe   68   0.364   0.932   0.284\n    0FE      Fe   69   0.506   0.790   0.142\n    0FE      Fe   70   0.364   0.932   0.568\n    0FE      Fe   71   0.506   0.790   0.426\n    0FE      Fe   72   0.364   1.216   0.000\n    0FE      Fe   73   0.364   1.216   0.284\n    0FE      Fe   74   0.506   1.074   0.142\n    0FE      Fe   75   0.364   1.216   0.568\n    0FE      Fe   76   0.506   1.074   0.426\n    0FE      Fe   77   0.364   1.500   0.000\n    0FE      Fe   78   0.364   1.500   0.284\n    0FE      Fe   79   0.506   1.358   0.142\n    0FE      Fe   80   0.364   1.500   0.568\n    0FE      Fe   81   0.506   1.358   0.426\n    0FE      Fe   82   0.364   1.784   0.000\n    0FE      Fe   83   0.364   1.784   0.284\n    0FE      Fe   84   0.506   1.642   0.142\n    0FE      Fe   85   0.364   1.784   0.568\n    ...

# %%
from ase.io import read
from ase.visualize import view
from ase import Atoms

def load_gro_with_box(filename):
    """
    Reads a .gro file and extracts atomic positions along with box dimensions.
    Returns:
        - atoms: ASE Atoms object containing atomic positions and box dimensions.
    """
    try:
        with open(filename, "r") as file:
            lines = file.readlines()
            
            # Parse the last line for box dimensions (in nm)
            box_line = lines[-1].split()
            if len(box_line) >= 3:
                box_dims = [float(dim) * 10 for dim in box_line[:3]]  # Convert nm to Å
                print(f"Extracted box dimensions (in Å): {box_dims}")
            else:
                box_dims = None
                print("Box dimensions not found or invalid.")
            
            # Load the atomic structure using ASE
            atoms = read(filename)
            
            # Assign box dimensions to the ASE Atoms object
            if box_dims:
                atoms.set_cell(box_dims)  # Set periodic box
                atoms.set_pbc(True)       # Enable periodic boundary conditions
            
            return atoms
    except FileNotFoundError:
        print(f"Error: File '{filename}' not found.")
        return None

def main():
    # Input .gro file
    gro_filename = "/mnt/newsitt/topic1/slab/conf.gro"
    
    # Load the structure with box dimensions
    atoms = load_gro_with_box(gro_filename)
    
    # Visualize the structure
    if atoms:
        view(atoms)
    else:
        print("Failed to load the .gro file.")

if __name__ == "__main__":
    main()
